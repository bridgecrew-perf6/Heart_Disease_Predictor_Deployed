# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.model_selection import train_test_split
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-1311b8747807> in <module>()
#       1 import numpy as np
# ----> 2 import pandas as pd
#       3 import os
#       4 import matplotlib.pyplot as plt
#       5 import xgboost as xgb
#
# E:\anaconda\lib\site-packages\pandas\__init__.py in <module>()
#      53 import pandas.core.config_init
#      54
# ---> 55 from pandas.core.api import (
#      56     # dtype
#      57     Int8Dtype,
#
# E:\anaconda\lib\site-packages\pandas\core\api.py in <module>()
#      21     DatetimeTZDtype,
#      22 )
# ---> 23 from pandas.core.arrays import Categorical, array
#      24 from pandas.core.groupby import Grouper, NamedAgg
#      25 from pandas.io.formats.format import set_eng_float_format
#
# E:\anaconda\lib\site-packages\pandas\core\arrays\__init__.py in <module>()
# ...

# %% [markdown]
# #### Create the dataframe

# %%
df=pd.read_csv('../input/heart-failure-prediction/heart.csv')

# %% [markdown]
# #### Check for missing values - there are none.

# %%
df.isnull().sum()

# %% [markdown]
# #### There are 918 records in the dataset

# %%
df.info()

# %% [markdown]
# #### Examine first few rows. The target is HeartDisease. There are 11 features.

# %%
df.head()

# %% [markdown]
# #### There appear to be no strong correlations amongst the numeric features.

# %%
plt.figure(1 , figsize = (16 , 8))
cor = sns.heatmap(df.corr(), annot = True)

# %% [markdown]
# #### Lets look at how the features are distributed

# %%
df.hist(figsize=(20,15))

# %% [markdown]
# #### Create the feature set by dropping the target column and replacing the categorial data with dummies

# %%
X=df.drop(columns = 'HeartDisease')
X=pd.get_dummies(X)

# %% [markdown]
# #### We now have 20 numeric features

# %%
print(X.columns)
print("Number of features = ", len(X.columns))

# %% [markdown]
# #### Create the dependent variable

# %%
y = df ['HeartDisease']

# %% [markdown]
# #### Train and fit the classifier using early stopping rounds to address overfitting

# %%
clf= xgb.XGBClassifier(n_estimators=1000,learning_rate=0.05,use_label_encoder=False )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7fd7337f4fdc> in <module>()
# ----> 1 clf= xgb.XGBClassifier(n_estimators=1000,learning_rate=0.05,use_label_encoder=False )
#
# NameError: name 'xgb' is not defined

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
clf.fit(X_train, y_train, early_stopping_rounds=5, eval_set=[(X_test, y_test)], verbose=False)

# %%
clf.best_iteration

# %% [markdown]
# #### Now we refit the model to make some predictions using the best n_estimator

# %%
clf= xgb.XGBClassifier(n_estimators = clf.best_iteration)

# %%
clf.fit(X_train, y_train)

# %% [markdown]
# #### Most important features according to this model

# %%
xgb.plot_importance(clf.fit(X_train,y_train))

# %% [markdown]
# #### Model score

# %%
clf.score(X_test,y_test)
